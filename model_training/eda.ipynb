# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d

# %% [markdown]
# <big>Doing some data visualizations!</big>

# %%
cook_df = pd.read_csv('./samples/cook.csv')
flick_df = pd.read_csv('./samples/flickup.csv')
jog_df = pd.read_csv('./samples/jog.csv')



# cook_df.info()
flick_df.info()
jog_df.info()

cook_x = cook_df["Ax"].to_numpy()
cook_y = cook_df["Ay"].to_numpy()
cook_z = cook_df["Az"].to_numpy()
cook_t = cook_df["Time"].to_numpy()

flick_x = flick_df["Ax"].to_numpy()
flick_y = flick_df["Ay"].to_numpy()
flick_z = flick_df["Az"].to_numpy()
flick_t = flick_df["Time"].to_numpy()

jog_x = jog_df["Ax"].to_numpy()
jog_y = jog_df["Ay"].to_numpy()
jog_z = jog_df["Az"].to_numpy()
jog_t = jog_df["Time"].to_numpy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5839 entries, 0 to 5838
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5839 non-null   int64
#  1   Ax      5839 non-null   float64
#  2   Ay      5839 non-null   float64
#  3   Az      5839 non-null   float64
#  4   Gx      5839 non-null   float64
#  5   Gy      5839 non-null   float64
#  6   Gz      5839 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 319.4 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5949 entries, 0 to 5948
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5949 non-null   int64
#  1   Ax      5949 non-null   float64
#  2   Ay      5949 non-null   float64
#  3   Az      5949 non-null   float64
#  4   Gx      5949 non-null   float64
#  5   Gy      5949 non-null   float64
#  6   Gz      5949 non-null   float64
# ...

# %%
#Cook Plots overlayed

fig, ax = plt.subplots()

ax.plot(cook_t, cook_x, label='X Acceleration')
ax.plot(cook_t, cook_y, label='Y Acceleration')
ax.plot(cook_t, cook_z, label='Z Acceleration')

ax.set_xlabel('Time')
ax.set_ylabel('Acceleration')
ax.legend()

plt.show()

# %%
fig1, ax1 = plt.subplots()
ax1.plot(cook_t, cook_x)
ax1.set_xlabel('Time')
ax1.set_ylabel('X Acceleration')

fig2, ax2 = plt.subplots()
ax2.plot(cook_t, cook_y, color= 'orange')
ax2.set_xlabel('Time')
ax2.set_ylabel('Y Acceleration')

fig3, ax3 = plt.subplots()
ax3.plot(cook_t, cook_z, color = 'green')
ax3.set_xlabel('Time')
ax3.set_ylabel('Z Acceleration')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Flick plots
fig, ax = plt.subplots()

ax.plot(flick_t, flick_x, label='X Acceleration')
ax.plot(flick_t, flick_y, label='Y Acceleration')
ax.plot(flick_t, flick_z, label='Z Acceleration')

ax.set_xlabel('Time')
ax.set_ylabel('Acceleration')
ax.legend()

plt.show()

# %%
fig1, ax1 = plt.subplots()
ax1.plot(flick_t, flick_x)
ax1.set_xlabel('Time')
ax1.set_ylabel('X Acceleration')

fig2, ax2 = plt.subplots()
ax2.plot(flick_t, flick_y, color= 'orange')
ax2.set_xlabel('Time')
ax2.set_ylabel('Y Acceleration')

fig3, ax3 = plt.subplots()
ax3.plot(flick_t, flick_z, color = 'green')
ax3.set_xlabel('Time')
ax3.set_ylabel('Z Acceleration')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig1, ax1 = plt.subplots()
ax1.plot(jog_t, jog_x)
ax1.set_xlabel('Time')
ax1.set_ylabel('X Acceleration')

fig2, ax2 = plt.subplots()
ax2.plot(jog_t, jog_y, color= 'orange')
ax2.set_xlabel('Time')
ax2.set_ylabel('Y Acceleration')

fig3, ax3 = plt.subplots()
ax3.plot(jog_t, jog_z, color = 'green')
ax3.set_xlabel('Time')
ax3.set_ylabel('Z Acceleration')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <big>Getting some info about the data</big>

# %%
print(cook_df.info())
print(flick_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 639 entries, 0 to 638
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    639 non-null    int64
#  1   Ax      639 non-null    float64
#  2   Ay      639 non-null    float64
#  3   Az      639 non-null    float64
#  4   Gx      639 non-null    float64
#  5   Gy      639 non-null    float64
#  6   Gz      639 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 35.1 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 634 entries, 0 to 633
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    634 non-null    int64
#  1   Ax      634 non-null    float64
#  2   Ay      634 non-null    float64
#  3   Az      634 non-null    float64
#  4   Gx      634 non-null    float64
#  5   Gy      634 non-null    float64
#  6   Gz      634 non-null    float64
# ...

# %%
print(cook_df.columns)
# Out:
# Index(['Time', 'Ax', 'Ay', 'Az', 'Gx', 'Gy', 'Gz'], dtype='object')

# %% [markdown]
# As can be seen, the last 5 elements of cook_df will need to be trimmed. Should probably consider making the time row a float as well.
